# %%
# Importing all necessary libraries
import cv2
import os

# %%
pwd
# Out:
# '/home/theekshana/Documents/visualDet3D'

# %%
video_path='./data/a.mp4'
video_frame_path='./data/video_frame'

# %%
# Read the video from specified path
cam = cv2.VideoCapture(video_path)

try:
	
	# creating a folder named data
	if not os.path.exists(video_frame_path):
		os.makedirs(video_frame_path)

# if not created then raise error
except OSError:
	print ('Error: Creating directory of data')

# frame
currentframe = 0

while(True):
	
	# reading from frame
	ret,frame = cam.read()

	if ret:
		# if video is still left continue creating images
		name = video_frame_path+'/' + str(currentframe) + '.jpg'
		print ('Creating...' + name)

		# writing the extracted images
		cv2.imwrite(name, frame)

		# increasing counter so that it will
		# show how many frames are created
		currentframe += 1
	else:
		break

# Release all space and windows once done
cam.release()
cv2.destroyAllWindows()
# Out:
# Creating..../data/video_frame/0.jpg
# Creating..../data/video_frame/1.jpg
# Creating..../data/video_frame/2.jpg
# Creating..../data/video_frame/3.jpg
# Creating..../data/video_frame/4.jpg
# Creating..../data/video_frame/5.jpg
# Creating..../data/video_frame/6.jpg
# Creating..../data/video_frame/7.jpg
# Creating..../data/video_frame/8.jpg
# Creating..../data/video_frame/9.jpg
# Creating..../data/video_frame/10.jpg
# Creating..../data/video_frame/11.jpg
# Creating..../data/video_frame/12.jpg
# Creating..../data/video_frame/13.jpg
# Creating..../data/video_frame/14.jpg
# Creating..../data/video_frame/15.jpg
# Creating..../data/video_frame/16.jpg
# Creating..../data/video_frame/17.jpg
# Creating..../data/video_frame/18.jpg
# Creating..../data/video_frame/19.jpg
# Creating..../data/video_frame/20.jpg
# Creating..../data/video_frame/21.jpg
# Creating..../data/video_frame/22.jpg
# Creating..../data/video_frame/23.jpg
# Creating..../data/video_frame/24.jpg
# ...

# %%
cap >> frame;
    Mat fullframe = frame(Rect(0, 0, 1280, 480 ));
    Mat leftframe= frame(Rect(0, 0, 640, 480));
    Mat rightframe= frame(Rect(640, 0, 640, 480));
